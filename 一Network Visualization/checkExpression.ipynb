# %%
import pandas as pd

# %%
regulatedGenes = pd.read_csv("../一Expression Heatmaps/geneExpressionData/Log2FoldAllGenes.csv")
regulatedGenes.rename(columns={"Unnamed: 0": "Genes"}, inplace=True)
regulatedGenes
# Out:
#             Genes  res_list.IN_2.log2FoldChange  res_list.IN_1.log2FoldChange  \
# 0       LINC01409                     -0.101252                      0.695545
# 1       LINC01128                     -0.230272                      0.435612
# 2      AL645608.6                     -1.139228                     -0.028647
# 3          SAMD11                      0.058968                      0.002499
# 4           NOC2L                      0.016235                      0.081964
# ...           ...                           ...                           ...
# 13783      MT-CYB                     -0.186749                      0.205875
# 13784  AC011043.1                      0.948745                      0.288975
# 13785  AL592183.1                      3.770575                      3.541074
# 13786  AC240274.1                      0.031538                     -0.347935
# 13787  AC004556.3                     -0.764642                     -0.316303
#
# ...

# %%
fRegulatedGenes = regulatedGenes[regulatedGenes["Genes"] == "SOX4"]
fRegulatedGenes
# Out:
#      Genes  res_list.IN_2.log2FoldChange  res_list.IN_1.log2FoldChange  \
# 4377  SOX4                     -0.116459                     -0.471883
#
#       res_list.IN.log2FoldChange  res_list.nIN_1.log2FoldChange  \
# 4377                    0.207683                      -0.236353
#
#       res_list.nIN.log2FoldChange  res_list.nEN_1.log2FoldChange  \
# 4377                    -0.012562                        0.44274
#
#       res_list.nEN.log2FoldChange  res_list.IPC.log2FoldChange  \
# 4377                     -0.11436                    -0.225544
#
#       res_list.MGE.log2FoldChange  res_list.RG.log2FoldChange      Mean
# 4377                    -1.171305                   -0.433446 -0.213149

# %%
fRegulatedGenes = regulatedGenes[regulatedGenes["Genes"] == "DLX5"]
fRegulatedGenes
# Out:
#      Genes  res_list.IN_2.log2FoldChange  res_list.IN_1.log2FoldChange  \
# 5359  DLX5                      0.104689                     -0.535358
#
#       res_list.IN.log2FoldChange  res_list.nIN_1.log2FoldChange  \
# 5359                   -0.547983                      -2.211216
#
#       res_list.nIN.log2FoldChange  res_list.nEN_1.log2FoldChange  \
# 5359                    -0.455092                      -0.416843
#
#       res_list.nEN.log2FoldChange  res_list.IPC.log2FoldChange  \
# 5359                    -1.512419                    -2.252765
#
#       res_list.MGE.log2FoldChange  res_list.RG.log2FoldChange      Mean
# 5359                    -1.812943                   -1.951641 -1.159157

# %%
fRegulatedGenes = regulatedGenes[regulatedGenes["Genes"] == "AUTS2"]
fRegulatedGenes
# Out:
#       Genes  res_list.IN_2.log2FoldChange  res_list.IN_1.log2FoldChange  \
# 5254  AUTS2                     -0.516329                     -1.022037
#
#       res_list.IN.log2FoldChange  res_list.nIN_1.log2FoldChange  \
# 5254                   -0.229014                      -0.797321
#
#       res_list.nIN.log2FoldChange  res_list.nEN_1.log2FoldChange  \
# 5254                    -0.636383                      -0.377884
#
#       res_list.nEN.log2FoldChange  res_list.IPC.log2FoldChange  \
# 5254                    -0.666974                    -0.757371
#
#       res_list.MGE.log2FoldChange  res_list.RG.log2FoldChange      Mean
# 5254                    -1.035635                   -0.892461 -0.693141

# %%
fRegulatedGenes = regulatedGenes[regulatedGenes["Genes"] == "SVBP"]
fRegulatedGenes
# Out:
#     Genes  res_list.IN_2.log2FoldChange  res_list.IN_1.log2FoldChange  \
# 392  SVBP                      0.167252                     -0.067209
#
#      res_list.IN.log2FoldChange  res_list.nIN_1.log2FoldChange  \
# 392                   -0.021542                      -0.009358
#
#      res_list.nIN.log2FoldChange  res_list.nEN_1.log2FoldChange  \
# 392                     0.053371                       0.631468
#
#      res_list.nEN.log2FoldChange  res_list.IPC.log2FoldChange  \
# 392                     0.136359                    -0.005811
#
#      res_list.MGE.log2FoldChange  res_list.RG.log2FoldChange      Mean
# 392                      -0.0842                    0.160202  0.096053
