# %%
import pandas as pd

# %%
####################################################################
# Import network
####################################################################

networkDS = pd.read_csv('./data/adjDataset.tsv', sep='\t')
networkDS
# Out:
#              TF      target    importance
# 0          RPL6        RPL9  4.349956e+02
# 1          RPL6        RPL5  4.060449e+02
# 2          RPL6       RPS3A  3.924514e+02
# 3          RPL6       RPL18  3.697235e+02
# 4          RPL6       RPL13  3.601602e+02
# ...         ...         ...           ...
# 183202    GTF3A       WDR47  4.335981e-10
# 183203   GTPBP6    RAP1GAP2  3.715861e-10
# 183204   GTPBP6    ADAMTS19  3.431918e-10
# 183205  SMARCB1     CCDC170  1.186833e-10
# 183206     GLI3  AC090348.1  1.091668e-10
#
# [183207 rows x 3 columns]

# %%
####################################################################
# Import lists of genes
####################################################################

# Import HSA21 genes
HSA21genesDataframe = pd.read_csv("./data/HSA21_genes_biomaRt_conversion.csv")
HSA21genes = [x for x in HSA21genesDataframe["hgnc_symbol"] if str(x) != 'nan']
len(HSA21genes)
# Out:
# 225

# %%
# Import more HSA21 genes
HSA21genesDataframeFull = pd.read_csv("./data/fullHSA21genes.csv")
HSA21genesFull = [x for x in HSA21genesDataframeFull["hgnc_symbol"] if str(x) != 'nan']

count = 0
for geneA in HSA21genes:
    if geneA in HSA21genesFull:
        count += 1
    else:
        HSA21genesFull.append(geneA)
HSA21genes = HSA21genesFull
len(HSA21genes)
# Out:
# 259

# %%
# Import Transcription Factors
TFsList = open("./data/TFs.txt", "r").read().split("\n")
len(TFsList)
# Out:
# 1840

# %%
# Create list for TFs that also are HSA21 genes
HSA21_TFs = []
for gene in HSA21genes:
    if gene in TFsList:
        HSA21_TFs.append(gene)

HSA21Regulators = [
    "ZNF294", "LTN1", "RNF160", 
    "ZNF295", "ZBTB21", "KIAA1227",
    "Pred65", "ZNF355P", "PRED65", 
    "ZNF298", "PRDM15", 
    "APECED", 
    "KIAA0136", "MORC3", "ZCWCC3", "NXP2",
    "GCFC", "PAXBP1", "GCFC1",
    "SON", "NREBP", "BASS1",
    "PKNOX1", "PREP1", 
    "HSF2BP", "MEILB2", "POF19",
    "NRIP1", "RIP140", "NRIP1"
]

HSA21_TFs += HSA21Regulators
HSA21_TFs
# Out:
# ['PRDM15',
#  'SOD1',
#  'GABPA',
#  'BACH1',
#  'ERG',
#  'ETS2',
#  'RUNX1',
#  'SIM2',
#  'HLCS',
#  'TFF3',
#  'PKNOX1',
#  'U2AF1',
#  'AIRE',
#  'OLIG1',
#  'ADARB1',
#  'OLIG2',
#  'ZNF294',
#  'LTN1',
#  'RNF160',
#  'ZNF295',
#  'ZBTB21',
#  'KIAA1227',
#  'Pred65',
#  'ZNF355P',
#  'PRED65',
#  'ZNF298',
#  'PRDM15',
#  'APECED',
#  'KIAA0136',
#  'MORC3',
#  'ZCWCC3',
#  'NXP2',
#  'GCFC',
#  'PAXBP1',
#  'GCFC1',
#  'SON',
#  'NREBP',
#  'BASS1',
#  'PKNOX1',
#  'PREP1',
#  'HSF2BP',
#  'MEILB2',
#  'POF19',
#  'NRIP1',
#  'RIP140',
#  'NRIP1']

# %%
# Import Neuro Development Disease genes
neuroDDdf = pd.read_csv('./data/NDDgenes.csv')
neuroDDdf = neuroDDdf[neuroDDdf["High Confidence NDD genes"] == True]
neuroDD = neuroDDdf["Symbol"].tolist()
len(neuroDD)
# Out:
# 1586

# %%
# Import NeuroDevelopmental Genes
neuroDevGenesDF = pd.read_csv('./data/NervousSystemDevelopmentGO.tsv', sep='\t')
neuroDevGenes = neuroDevGenesDF["Gene"].tolist()
len(neuroDevGenes)
# Select only relevant GO Terms
# In this case I have decided to include all genes
# Out:
# 4815

# %%
regulatedGenes = pd.read_csv('./data/superGeneOrderDataframe-pval<0.01.csv')
regulatedGenes = regulatedGenes.set_index('Gene')
regulatedGenes['Mean'] = regulatedGenes.mean(axis=1)
upDownRegulated = regulatedGenes['Mean'].to_dict()
regulatedGenes
# Out:
#                 IN_2      IN_1        IN     nIN_1       nIN     nEN_1  \
# Gene
# LINC01409   0.347271 -0.663075 -0.668930  0.855479 -2.944556  0.425603
# LINC01128   0.345923 -2.846940  0.591948  0.402350 -2.859292  0.828230
# AL645608.6  1.217709  0.099018 -0.154763  1.322247 -1.647330  0.896042
# SAMD11     -0.336866 -0.467202 -0.241348  0.353962 -1.370589  1.800136
# NOC2L      -0.148234 -0.217521 -0.487569  0.522000  1.077892  0.529973
# ...              ...       ...       ...       ...       ...       ...
# MT-CYB      0.195976 -0.272919  0.199545  0.281428 -0.304296  0.310947
# AC011043.1 -1.000879 -0.105622  0.699476  0.987021 -2.839346  0.454375
# AL592183.1 -1.028316 -1.009383 -3.073957 -2.159972 -1.080623 -1.078441
# AC240274.1 -0.065734  0.568319  0.523530  0.587644 -2.673716  0.299896
# AC004556.3  1.554652 -0.991852  2.810703  1.743580 -0.666812  0.105826
#
#                  nEN       IPC       MGE        RG      Mean
# Gene
# LINC01409   0.174239 -0.126681  0.095841 -0.064386 -0.256919
# LINC01128   0.712282 -1.413110 -0.098942 -0.012728 -0.435028
# AL645608.6  0.543718 -0.211704 -0.814285 -0.147440  0.110321
# SAMD11      0.165134 -0.555332  0.240605 -0.696171 -0.110767
# NOC2L      -0.147666 -0.142678 -0.488490 -0.114286  0.038342
# ...              ...       ...       ...       ...       ...
# MT-CYB     -0.177389  0.045330  0.097074 -0.038290  0.033741
# AC011043.1  0.246574 -0.028093  0.449371  0.094934 -0.104219
# AL592183.1 -2.316533 -2.339817 -0.874355 -1.421793 -1.638319
# AC240274.1  0.592940  0.474852  0.518068  0.487736  0.131354
# AC004556.3  1.548532  1.721582  1.285485  1.222507  1.033420
#
# [13788 rows x 11 columns]

# %%
####################################################################
# Map list of genes on networkDS
####################################################################

# Filter network at 50 importance
networkDS = networkDS[networkDS["importance"]>80]

# Type of lists
# HSA21genes TFsList HSA21_TFs neuroDD neuroDevGenes
listDict = {
    "GeneralTF": TFsList,
    "NeuroDev": neuroDevGenes,
    "NeuroDisease": neuroDD,
    "HSA21gene": HSA21genes,
    "HSA21TF": HSA21_TFs,
}
networkDS
# Out:
#          TF   target  importance
# 0      RPL6     RPL9  434.995598
# 1      RPL6     RPL5  406.044919
# 2      RPL6    RPS3A  392.451358
# 3      RPL6    RPL18  369.723475
# 4      RPL6    RPL13  360.160228
# ..      ...      ...         ...
# 505  RBFOX2   TNRC6A   80.201329
# 506  HIVEP3  KIRREL3   80.183544
# 507   ESRRG   DCBLD2   80.181700
# 508   SOX11     CD24   80.172893
# 509   CELF4     DNM3   80.045663
#
# [510 rows x 3 columns]

# %%
# Give type to TFs
listOfTFs = networkDS["TF"].tolist()
TF_Type = []
geneExpressionTF = []

for gene in listOfTFs:
    value = "None"
    for key in listDict:
        if gene in listDict[key]:
            value = key
    TF_Type.append(value)
    geneExpressionTF.append(upDownRegulated[gene])

networkDS["TF_Type"] =  TF_Type
networkDS["TF_Expression"] =  geneExpressionTF
networkDS
# Out:
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_5566/4279029347.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["TF_Type"] =  TF_Type
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_5566/4279029347.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["TF_Expression"] =  geneExpressionTF
#          TF   target  importance       TF_Type  TF_Expression
# 0      RPL6     RPL9  434.995598     GeneralTF      -0.272356
# 1      RPL6     RPL5  406.044919     GeneralTF      -0.272356
# 2      RPL6    RPS3A  392.451358     GeneralTF      -0.272356
# 3      RPL6    RPL18  369.723475     GeneralTF      -0.272356
# 4      RPL6    RPL13  360.160228     GeneralTF      -0.272356
# ..      ...      ...         ...           ...            ...
# 505  RBFOX2   TNRC6A   80.201329      NeuroDev       0.134265
# 506  HIVEP3  KIRREL3   80.183544  NeuroDisease      -0.006192
# 507   ESRRG   DCBLD2   80.181700     GeneralTF       0.056735
# 508   SOX11     CD24   80.172893  NeuroDisease       0.242335
# 509   CELF4     DNM3   80.045663  NeuroDisease       0.163573
#
# [510 rows x 5 columns]

# %%
# Give type to Targets
listOfTargets = networkDS["target"].tolist()
Target_Type = []
geneExpressionTarget = []

for gene in listOfTargets:
    value = "None"
    for key in listDict:
        if gene in listDict[key]:
            value = key
    Target_Type.append(value)
    geneExpressionTarget.append(upDownRegulated[gene])

networkDS["Target_Type"] =  Target_Type
networkDS["Target_Expression"] =  geneExpressionTarget
networkDS
# Out:
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_5566/2793024573.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["Target_Type"] =  Target_Type
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_5566/2793024573.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["Target_Expression"] =  geneExpressionTarget
#          TF   target  importance       TF_Type  TF_Expression Target_Type  \
# 0      RPL6     RPL9  434.995598     GeneralTF      -0.272356        None
# 1      RPL6     RPL5  406.044919     GeneralTF      -0.272356        None
# 2      RPL6    RPS3A  392.451358     GeneralTF      -0.272356        None
# 3      RPL6    RPL18  369.723475     GeneralTF      -0.272356        None
# 4      RPL6    RPL13  360.160228     GeneralTF      -0.272356        None
# ..      ...      ...         ...           ...            ...         ...
# 505  RBFOX2   TNRC6A   80.201329      NeuroDev       0.134265        None
# 506  HIVEP3  KIRREL3   80.183544  NeuroDisease      -0.006192    NeuroDev
# 507   ESRRG   DCBLD2   80.181700     GeneralTF       0.056735        None
# 508   SOX11     CD24   80.172893  NeuroDisease       0.242335        None
# 509   CELF4     DNM3   80.045663  NeuroDisease       0.163573    NeuroDev
#
#      Target_Expression
# 0            -0.358896
# 1            -0.224570
# 2            -0.315155
# 3            -0.312842
# 4            -0.346991
# ..                 ...
# 505           0.188093
# 506           0.567114
# 507           0.027968
# 508           0.943253
# 509           0.979948
#
# [510 rows x 7 columns]

# %%
networkDS.to_csv("filteredNetwork.csv", index=False)

# %%
networkOnlyHSA21TF = networkDS[networkDS["TF_Type"]=="HSA21TF"]
networkOnlyHSA21TF
# Out:
# Empty DataFrame
# Columns: [TF, target, importance, TF_Type, TF_Expression, Target_Type, Target_Expression]
# Index: []

# %%
networkOnlyHSA21gene = networkDS[networkDS["Target_Type"]=="HSA21gene"]
networkOnlyHSA21gene
# Out:
#         TF  target  importance       TF_Type  TF_Expression Target_Type  \
# 177   YBX1  ATP5PF  124.237070     GeneralTF      -0.104825   HSA21gene
# 178   YBX1   HMGN1  124.210839     GeneralTF      -0.104825   HSA21gene
# 192   YBX1  ATP5PO  118.945785     GeneralTF      -0.104825   HSA21gene
# 194   RPL6  ATP5PO  118.674212     GeneralTF      -0.272356   HSA21gene
# 221   RPL6    CCT8  112.514822     GeneralTF      -0.272356   HSA21gene
# 288   YBX1    CCT8  102.022463     GeneralTF      -0.104825   HSA21gene
# 307   SOX4    TTC3   99.449793  NeuroDisease       0.232811   HSA21gene
# 380   RPL6    CSTB   90.248448     GeneralTF      -0.272356   HSA21gene
# 381   RPL6  ATP5PF   89.788768     GeneralTF      -0.272356   HSA21gene
# 468  CERS6  DYRK1A   82.677338     GeneralTF       0.287057   HSA21gene
# 484  CELF4   CXADR   81.308279  NeuroDisease       0.163573   HSA21gene
#
#      Target_Expression
# 177           0.497139
# 178           0.445579
# 192           0.546199
# 194           0.546199
# 221           0.631660
# 288           0.631660
# 307           0.597673
# 380           0.402816
# 381           0.497139
# 468           0.618291
# 484           0.593612

# %%
networkTest = networkDS[networkDS["Target_Type"]=="None"]
networkTest
# Out:
#          TF  target  importance       TF_Type  TF_Expression Target_Type  \
# 0      RPL6    RPL9  434.995598     GeneralTF      -0.272356        None
# 1      RPL6    RPL5  406.044919     GeneralTF      -0.272356        None
# 2      RPL6   RPS3A  392.451358     GeneralTF      -0.272356        None
# 3      RPL6   RPL18  369.723475     GeneralTF      -0.272356        None
# 4      RPL6   RPL13  360.160228     GeneralTF      -0.272356        None
# ..      ...     ...         ...           ...            ...         ...
# 499   HMGN3    CDO1   80.623957     GeneralTF      -0.220257        None
# 500    RPL6  POLR2I   80.476348     GeneralTF      -0.272356        None
# 505  RBFOX2  TNRC6A   80.201329      NeuroDev       0.134265        None
# 507   ESRRG  DCBLD2   80.181700     GeneralTF       0.056735        None
# 508   SOX11    CD24   80.172893  NeuroDisease       0.242335        None
#
#      Target_Expression
# 0            -0.358896
# 1            -0.224570
# 2            -0.315155
# 3            -0.312842
# 4            -0.346991
# ..                 ...
# 499          -0.204829
# 500          -0.058733
# 505           0.188093
# 507           0.027968
# 508           0.943253
#
# [316 rows x 7 columns]

# %%
networkTest = networkDS[networkDS["TF_Type"]=="None"]
networkTest
# Out:
# Empty DataFrame
# Columns: [TF, target, importance, TF_Type, TF_Expression, Target_Type, Target_Expression]
# Index: []
