# %%
import pandas as pd

# %%
####################################################################
# Import network
####################################################################

networkDS = pd.read_csv('./data/adjDatasetFullGenes.tsv', sep='\t')
networkDS
# Out:
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_24456/104746886.py:5: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   networkDS = pd.read_csv('./data/adjDatasetFullGenes.tsv', sep='\t')
#              TF      target  importance
# 0        GABPB1       CELF4  654.725767
# 1         PROX2       OLFM2  646.050355
# 2        ZNF114       AUTS2  443.843549
# 3           EZR  AC091885.2  431.551171
# 4          RFX4  AC079385.1  404.289890
# ...         ...         ...         ...
# 1046523     NaN         NaN         NaN
# 1046524     NaN         NaN         NaN
# 1046525     NaN         NaN         NaN
# 1046526     NaN         NaN         NaN
# 1046527     NaN         NaN         NaN
#
# [1046528 rows x 3 columns]

# %%
####################################################################
# Import lists of genes
####################################################################

# Import HSA21 genes
HSA21genesDataframe = pd.read_csv("./data/HSA21_genes_biomaRt_conversion.csv")
HSA21genes = [x for x in HSA21genesDataframe["hgnc_symbol"] if str(x) != 'nan']
len(HSA21genes)
# Out:
# 225

# %%
# Import more HSA21 genes
HSA21genesDataframeFull = pd.read_csv("./data/fullHSA21genes.csv")
HSA21genesFull = [x for x in HSA21genesDataframeFull["hgnc_symbol"] if str(x) != 'nan']

count = 0
for geneA in HSA21genes:
    if geneA in HSA21genesFull:
        count += 1
    else:
        HSA21genesFull.append(geneA)
HSA21genes = HSA21genesFull
len(HSA21genes)
# Out:
# 259

# %%
# Import Transcription Factors
TFsList = open("./data/TFs.txt", "r").read().split("\n")
len(TFsList)
# Out:
# 1840

# %%
# Create list for TFs that also are HSA21 genes
HSA21_TFs = []
for gene in HSA21genes:
    if gene in TFsList:
        HSA21_TFs.append(gene)

HSA21Regulators = [
    "ZNF294", "LTN1", "RNF160", 
    "ZNF295", "ZBTB21", "KIAA1227",
    "Pred65", "ZNF355P", "PRED65", 
    "ZNF298", "PRDM15", 
    "APECED", 
    "KIAA0136", "MORC3", "ZCWCC3", "NXP2",
    "GCFC", "PAXBP1", "GCFC1",
    "SON", "NREBP", "BASS1",
    "PKNOX1", "PREP1", 
    "HSF2BP", "MEILB2", "POF19",
    "NRIP1", "RIP140", "NRIP1"
]

HSA21_TFs += HSA21Regulators
HSA21_TFs
# Out:
# ['PRDM15',
#  'SOD1',
#  'GABPA',
#  'BACH1',
#  'ERG',
#  'ETS2',
#  'RUNX1',
#  'SIM2',
#  'HLCS',
#  'TFF3',
#  'PKNOX1',
#  'U2AF1',
#  'AIRE',
#  'OLIG1',
#  'ADARB1',
#  'OLIG2',
#  'ZNF294',
#  'LTN1',
#  'RNF160',
#  'ZNF295',
#  'ZBTB21',
#  'KIAA1227',
#  'Pred65',
#  'ZNF355P',
#  'PRED65',
#  'ZNF298',
#  'PRDM15',
#  'APECED',
#  'KIAA0136',
#  'MORC3',
#  'ZCWCC3',
#  'NXP2',
#  'GCFC',
#  'PAXBP1',
#  'GCFC1',
#  'SON',
#  'NREBP',
#  'BASS1',
#  'PKNOX1',
#  'PREP1',
#  'HSF2BP',
#  'MEILB2',
#  'POF19',
#  'NRIP1',
#  'RIP140',
#  'NRIP1']

# %%
# Import Neuro Development Disease genes
neuroDDdf = pd.read_csv('./data/NDDgenes.csv')
neuroDDdf = neuroDDdf[neuroDDdf["High Confidence NDD genes"] == True]
neuroDD = neuroDDdf["Symbol"].tolist()
len(neuroDD)
# Out:
# 1586

# %%
# Import NeuroDevelopmental Genes
neuroDevGenesDF = pd.read_csv('./data/NervousSystemDevelopmentGO.tsv', sep='\t')
neuroDevGenes = neuroDevGenesDF["Gene"].tolist()
len(neuroDevGenes)
# Select only relevant GO Terms
# In this case I have decided to include all genes
# Out:
# 4815

# %%
regulatedGenes = pd.read_csv('./data/superGeneOrderDataframe-pval<0.01.csv')
regulatedGenes = regulatedGenes.set_index('Gene')
regulatedGenes['Mean'] = regulatedGenes.mean(axis=1)
upDownRegulated = regulatedGenes['Mean'].to_dict()
regulatedGenes
# Out:
#                 IN_2      IN_1        IN     nIN_1       nIN     nEN_1  \
# Gene
# LINC01409   0.347271 -0.663075 -0.668930  0.855479 -2.944556  0.425603
# LINC01128   0.345923 -2.846940  0.591948  0.402350 -2.859292  0.828230
# AL645608.6  1.217709  0.099018 -0.154763  1.322247 -1.647330  0.896042
# SAMD11     -0.336866 -0.467202 -0.241348  0.353962 -1.370589  1.800136
# NOC2L      -0.148234 -0.217521 -0.487569  0.522000  1.077892  0.529973
# ...              ...       ...       ...       ...       ...       ...
# MT-CYB      0.195976 -0.272919  0.199545  0.281428 -0.304296  0.310947
# AC011043.1 -1.000879 -0.105622  0.699476  0.987021 -2.839346  0.454375
# AL592183.1 -1.028316 -1.009383 -3.073957 -2.159972 -1.080623 -1.078441
# AC240274.1 -0.065734  0.568319  0.523530  0.587644 -2.673716  0.299896
# AC004556.3  1.554652 -0.991852  2.810703  1.743580 -0.666812  0.105826
#
#                  nEN       IPC       MGE        RG      Mean
# Gene
# LINC01409   0.174239 -0.126681  0.095841 -0.064386 -0.256919
# LINC01128   0.712282 -1.413110 -0.098942 -0.012728 -0.435028
# AL645608.6  0.543718 -0.211704 -0.814285 -0.147440  0.110321
# SAMD11      0.165134 -0.555332  0.240605 -0.696171 -0.110767
# NOC2L      -0.147666 -0.142678 -0.488490 -0.114286  0.038342
# ...              ...       ...       ...       ...       ...
# MT-CYB     -0.177389  0.045330  0.097074 -0.038290  0.033741
# AC011043.1  0.246574 -0.028093  0.449371  0.094934 -0.104219
# AL592183.1 -2.316533 -2.339817 -0.874355 -1.421793 -1.638319
# AC240274.1  0.592940  0.474852  0.518068  0.487736  0.131354
# AC004556.3  1.548532  1.721582  1.285485  1.222507  1.033420
#
# [13788 rows x 11 columns]

# %%
####################################################################
# Map list of genes on networkDS
####################################################################

# Filter network at 50 importance
networkDS = networkDS[networkDS["importance"]>80]

# Type of lists
# HSA21genes TFsList HSA21_TFs neuroDD neuroDevGenes
listDict = {
    "GeneralTF": TFsList,
    "NeuroDev": neuroDevGenes,
    "NeuroDisease": neuroDD,
    "HSA21gene": HSA21genes,
    "HSA21TF": HSA21_TFs,
}
networkDS
# Out:
#            TF      target  importance
# 0      GABPB1       CELF4  654.725767
# 1       PROX2       OLFM2  646.050355
# 2      ZNF114       AUTS2  443.843549
# 3         EZR  AC091885.2  431.551171
# 4        RFX4  AC079385.1  404.289890
# ...       ...         ...         ...
# 2020    FOXK2    PPARGC1B   83.229989
# 2021    CELF4       PTPRO   83.217277
# 2022  HNRNPA1       RPL34   83.210962
# 2023   RBFOX2       STMN4   83.210936
# 2024     SOX4        NSG1   83.201163
#
# [2025 rows x 3 columns]

# %%
# Give type to TFs
listOfTFs = networkDS["TF"].tolist()
TF_Type = []
geneExpressionTF = []

for gene in listOfTFs:
    value = "None"
    for key in listDict:
        if gene in listDict[key]:
            value = key
    TF_Type.append(value)
    try:
        geneExpressionTF.append(upDownRegulated[gene])
    except:
        geneExpressionTF.append("Not Known")

networkDS["TF_Type"] =  TF_Type
networkDS["TF_Expression"] =  geneExpressionTF
networkDS
# Out:
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_24456/1635619374.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["TF_Type"] =  TF_Type
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_24456/1635619374.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["TF_Expression"] =  geneExpressionTF
#            TF      target  importance       TF_Type TF_Expression
# 0      GABPB1       CELF4  654.725767     GeneralTF     -0.070045
# 1       PROX2       OLFM2  646.050355      NeuroDev     Not Known
# 2      ZNF114       AUTS2  443.843549     GeneralTF      0.033013
# 3         EZR  AC091885.2  431.551171     GeneralTF     -0.837765
# 4        RFX4  AC079385.1  404.289890      NeuroDev      0.015713
# ...       ...         ...         ...           ...           ...
# 2020    FOXK2    PPARGC1B   83.229989     GeneralTF      0.075858
# 2021    CELF4       PTPRO   83.217277  NeuroDisease      0.163573
# 2022  HNRNPA1       RPL34   83.210962     GeneralTF     -0.117636
# 2023   RBFOX2       STMN4   83.210936      NeuroDev      0.134265
# 2024     SOX4        NSG1   83.201163  NeuroDisease      0.232811
#
# [2025 rows x 5 columns]

# %%
# Give type to Targets
listOfTargets = networkDS["target"].tolist()
Target_Type = []
geneExpressionTarget = []

for gene in listOfTargets:
    value = "None"
    for key in listDict:
        if gene in listDict[key]:
            value = key
    Target_Type.append(value)
    try:
        geneExpressionTarget.append(upDownRegulated[gene])
    except:
        geneExpressionTarget.append("Not Known")

networkDS["Target_Type"] =  Target_Type
networkDS["Target_Expression"] =  geneExpressionTarget
networkDS
# Out:
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_24456/4004021025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["Target_Type"] =  Target_Type
# /var/folders/ts/m7c_798d70q3whk59gstkgz00000gn/T/ipykernel_24456/4004021025.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   networkDS["Target_Expression"] =  geneExpressionTarget
#            TF      target  importance       TF_Type TF_Expression  \
# 0      GABPB1       CELF4  654.725767     GeneralTF     -0.070045
# 1       PROX2       OLFM2  646.050355      NeuroDev     Not Known
# 2      ZNF114       AUTS2  443.843549     GeneralTF      0.033013
# 3         EZR  AC091885.2  431.551171     GeneralTF     -0.837765
# 4        RFX4  AC079385.1  404.289890      NeuroDev      0.015713
# ...       ...         ...         ...           ...           ...
# 2020    FOXK2    PPARGC1B   83.229989     GeneralTF      0.075858
# 2021    CELF4       PTPRO   83.217277  NeuroDisease      0.163573
# 2022  HNRNPA1       RPL34   83.210962     GeneralTF     -0.117636
# 2023   RBFOX2       STMN4   83.210936      NeuroDev      0.134265
# 2024     SOX4        NSG1   83.201163  NeuroDisease      0.232811
#
#        Target_Type Target_Expression
# 0     NeuroDisease          0.163573
# 1             None         -0.038916
# 2     NeuroDisease          1.016159
# 3             None         -0.330419
# 4             None          0.238794
# ...            ...               ...
# 2020          None         -0.206109
# 2021      NeuroDev          0.413114
# 2022          None         -0.268919
# 2023      NeuroDev          0.029382
# 2024          None          0.279992
#
# [2025 rows x 7 columns]

# %%
networkDS.to_csv("filteredNetwork.csv", index=False)

# %%
networkOnlyHSA21TF = networkDS[networkDS["TF_Type"]=="HSA21TF"]
networkOnlyHSA21TF
# Out:
#         TF      target  importance  TF_Type TF_Expression Target_Type  \
# 1554  HLCS  AP001527.2    91.75553  HSA21TF      0.723267        None
#
#      Target_Expression
# 1554         Not Known

# %%
networkOnlyHSA21gene = networkDS[networkDS["Target_Type"]=="HSA21gene"]
networkOnlyHSA21gene
# Out:
#           TF  target  importance       TF_Type TF_Expression Target_Type  \
# 453    STAT1     MX1  141.184599     GeneralTF     -0.613072   HSA21gene
# 569    ZNF76  IFNGR2  131.742595      NeuroDev     -0.245837   HSA21gene
# 1075    RPL6    CCT8  105.762445     GeneralTF     -0.272356   HSA21gene
# 1145   RPS4X  ATP5PO  103.307084     GeneralTF     -0.162235   HSA21gene
# 1302    RPL6  ATP5PF   97.908568     GeneralTF     -0.272356   HSA21gene
# 1362  RBFOX2   CXADR   96.452629      NeuroDev      0.134265   HSA21gene
# 1407    SOX4    TTC3   95.302935  NeuroDisease      0.232811   HSA21gene
# 1522  RBFOX2    TTC3   92.558569      NeuroDev      0.134265   HSA21gene
# 1640   CELF4   CXADR   89.998086  NeuroDisease      0.163573   HSA21gene
# 1700   DMRT1   RCAN1   88.892777     GeneralTF     Not Known   HSA21gene
# 1822   HMGB1   HMGN1   86.651559      NeuroDev     -0.123166   HSA21gene
# 1824    SOX4   CXADR   86.593017  NeuroDisease      0.232811   HSA21gene
#
#      Target_Expression
# 453          Not Known
# 569           0.619737
# 1075           0.63166
# 1145          0.546199
# 1302          0.497139
# 1362          0.593612
# 1407          0.597673
# 1522          0.597673
# 1640          0.593612
# 1700          0.494321
# 1822          0.445579
# 1824          0.593612

# %%
networkTest = networkDS[networkDS["Target_Type"]=="None"]
networkTest
# Out:
#            TF      target  importance       TF_Type TF_Expression Target_Type  \
# 1       PROX2       OLFM2  646.050355      NeuroDev     Not Known        None
# 3         EZR  AC091885.2  431.551171     GeneralTF     -0.837765        None
# 4        RFX4  AC079385.1  404.289890      NeuroDev      0.015713        None
# 5      ZNF362     PLEKHA6  382.869764     GeneralTF     -0.137829        None
# 6        ENO1      IGFBP2  359.394299     GeneralTF     -0.536833        None
# ...       ...         ...         ...           ...           ...         ...
# 2017    RPS10     COX7A2L   83.278118     GeneralTF      -0.09295        None
# 2018    CTCFL        SIK3   83.250499     GeneralTF     Not Known        None
# 2020    FOXK2    PPARGC1B   83.229989     GeneralTF      0.075858        None
# 2022  HNRNPA1       RPL34   83.210962     GeneralTF     -0.117636        None
# 2024     SOX4        NSG1   83.201163  NeuroDisease      0.232811        None
#
#      Target_Expression
# 1            -0.038916
# 3            -0.330419
# 4             0.238794
# 5            -0.453836
# 6            -0.686301
# ...                ...
# 2017         -0.147095
# 2018         -0.001355
# 2020         -0.206109
# 2022         -0.268919
# 2024          0.279992
#
# [1342 rows x 7 columns]

# %%
networkTest = networkDS[networkDS["TF_Type"]=="None"]
networkTest
# Out:
# Empty DataFrame
# Columns: [TF, target, importance, TF_Type, TF_Expression, Target_Type, Target_Expression]
# Index: []
