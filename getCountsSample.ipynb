# %%
from itertools import groupby
from json import load
import pandas as pd
import scanpy as sc
import numpy as np
import sys
import tests.loadScanpy as loadScanpy
import modules.classifyClusters.classifyClusters as classify
import os
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

####################################################################################################
# Global Settings 
####################################################################################################
np.set_printoptions(threshold=sys.maxsize)
pd.options.display.max_columns = sys.maxsize
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)

inputData = "./output/savedData.h5ad" # ./dataSaveOriginal/rawDataset5000.h5ad
results_file = './output/savedData.h5ad'
outputDirectory = "./outputPDFs/"

# %%
adata = sc.read(inputData)
adata.var_names_make_unique()
adata.X = adata.X.astype('float64')

# %%
def getColSample(sample, leiden):
    if leiden == "":
        subset =  adata[adata.obs["sample"] == sample]
        returnArray = [sum(x) for x in zip(*subset.X)]
        return returnArray[0].toarray()[0] #returnArray[0].toarray()[0]
    else:
        subset =  adata[adata.obs["sample"] == sample]
        print(subset)
        subset = subset[subset.obs["leiden"] == leiden]
        print(subset)
        returnArray = [sum(x) for x in zip(*subset.X)]
        print(len(returnArray))
        return returnArray #returnArray[0].toarray()[0]

rows = adata.var["features"].values

# CON_DS2U CON_H9 CON_IMR CON_ihtc DS_2DS3 DS_DS1 DS_DSP
listLeiden = adata.obs["leiden"].unique().tolist()

df = pd.DataFrame(rows, columns=['id'])

for item in listLeiden:
    print("1")
    df["CON_DS2U"] = getColSample("CON_DS2U", item)
    print("2")
    df["CON_H9"] = getColSample("CON_H9", item)
    print("3")
    df["CON_IMR"] = getColSample("CON_IMR", item)
    print("4")
    df["DS_2DS3"] = getColSample("DS_2DS3", item)
    print("5")
    df["DS_DSP"] = getColSample("DS_DSP", item)


df = df.set_index('id')
df
# Out:
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 43 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 2
# View of AnnData object with n_obs × n_vars = 411 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 26 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 123 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 9 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 5
# View of AnnData object with n_obs × n_vars = 727 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 163 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 237 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 2
# View of AnnData object with n_obs × n_vars = 411 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 55 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 217 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 73 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 5
# View of AnnData object with n_obs × n_vars = 727 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 12 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 158 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 2
# View of AnnData object with n_obs × n_vars = 411 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 95 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 198 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 56 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 5
# View of AnnData object with n_obs × n_vars = 727 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 9 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 67 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 2
# View of AnnData object with n_obs × n_vars = 411 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 34 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 52 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 17 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 5
# View of AnnData object with n_obs × n_vars = 727 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 84 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 154 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 2
# View of AnnData object with n_obs × n_vars = 411 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 38 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 205 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 58 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 5
# View of AnnData object with n_obs × n_vars = 727 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 104 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 33 × 7303
# ...
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 79 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 199 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 5
# View of AnnData object with n_obs × n_vars = 727 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 169 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 1
# View of AnnData object with n_obs × n_vars = 764 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 35 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 2
# View of AnnData object with n_obs × n_vars = 411 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 5 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 3
# View of AnnData object with n_obs × n_vars = 1006 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 57 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 7303
# 4
# View of AnnData object with n_obs × n_vars = 633 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# View of AnnData object with n_obs × n_vars = 0 × 7303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'group', 'sample', 'percentMito', 'percent_reads_top50', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'clust_orig', 'clust_orig_lab', 'clust_recl', 'integrated_snn_res.0.8', 'cluster_type', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percentageTop50', 'n_genes', 'leiden'
#     var: 'features', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_group', 'dendrogram_leiden', 'group_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 30
#      28 df["CON_IMR"] = getColSample("CON_IMR", item)
#      29 print("4")
# ---> 30 df["DS_2DS3"] = getColSample("DS_2DS3", item)
#      31 print("5")
#      32 df["DS_DSP"] = getColSample("DS_DSP", item)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:4538, in DataFrame._sanitize_column(self, value)
#    4535     return _reindex_for_setitem(value, self.index)
#    4537 if is_list_like(value):
# -> 4538     com.require_length_match(value, self.index)
#    4539 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (0) does not match length of index (7303)

# %%
df.to_csv('rawCountsDESeqPerCluster.csv')
