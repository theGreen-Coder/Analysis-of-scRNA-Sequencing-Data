# %%
import pandas as pd

# %%
significantGenes = pd.read_csv("significantGenesLog2Fold>5.8.csv")

# %%
listSignificantGenes = significantGenes["x"].to_list()

# %%
testList = []
duplicated = 0

for gene in listSignificantGenes:
    if gene in testList:
        duplicated += 1
    else:
        testList.append(gene)
    
    if gene == "OLIG2":
        print("Found AUTS2 in DE genes")

# %%
duplicated
# Out:
# 0

# %%
len(listSignificantGenes)
# Out:
# 13763

# %%
listSignificantGenes
# Out:
# ['C4orf19',
#  'PRDM5',
#  'TRIM5',
#  'NBPF26',
#  'HEG1',
#  'LINC02388',
#  'AC020687.1',
#  'B3GNT2',
#  'COL27A1',
#  'MIR222HG',
#  'GPD2',
#  'NR4A3',
#  'MSRB3',
#  'TMCC1-AS1',
#  'AC107072.2',
#  'PMP2',
#  'IFITM2',
#  'HS3ST3A1',
#  'CXCL14',
#  'AC108861.1',
#  'TNFRSF10D',
#  'CNKSR3',
#  'AC083906.3',
#  'VRK2',
#  'DAPK2',
#  'ANOS1',
#  'FOSB',
#  'FST',
#  'IRX2',
#  'SNTB1',
#  'AC092675.1',
#  'AC079298.3',
#  'MYO1E',
#  'DGKB',
#  'ARHGAP42',
#  'ADAMTS9',
#  'LYPD6',
#  'MIR17HG',
#  'ILDR2',
#  'AC119674.1',
#  'ABCC4',
#  'ANTXR2',
#  'MCC',
#  'AC109129.1',
#  'AC002069.2',
#  'CCNJL',
#  'SLC6A16',
#  'AASS',
#  'LINC01707',
#  'LINC02249',
#  'FREM2',
#  'LUCAT1',
#  'MIR34AHG',
#  'LOX',
#  'DPP4',
#  'THSD4',
#  'SLC7A11',
#  'NR2E3',
#  'DRAM1',
#  'NOSTRIN',
#  'AL356094.2',
#  'OSBPL3',
#  'MIR9-3HG',
#  'EIF5A2',
#  'MEGF6',
#  'CYP27C1',
#  'DERA',
#  'CLEC2D',
#  'KCNN3',
#  'FAM13A',
#  'CNTLN',
#  'MTAP',
#  'PLEKHG1',
#  'PAWR',
#  'NCALD',
# ...
