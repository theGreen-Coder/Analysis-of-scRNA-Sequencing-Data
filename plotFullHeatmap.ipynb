# %%
import pandas as pd
import seaborn as sns

heatMapPlot = pd.read_csv("./outputPDFs/DiffExpOut/matScaledFullDataset.csv")
heatMapPlot = heatMapPlot.set_index(['Unnamed: 0'])
heatMapPlot
# Out:
#             CON_DS2U.EN_1  CON_H9.EN_1  CON_IMR.EN_1  DS_2DS3.EN_1  \
# Unnamed: 0
# AL627309.1      -0.205257     0.029635      0.601301     -1.536627
# AL627309.5      -1.060212     0.652904      0.949735      0.565613
# LINC01409        1.187852    -1.544180     -0.118466      0.434586
# LINC01128       -0.200137     0.295025     -0.835778      1.574588
# LINC00115       -0.213972     1.656303     -0.103494     -1.059241
# ...                   ...          ...           ...           ...
# AL592183.1      -0.456150    -0.548309      1.775754     -0.528007
# AC240274.1      -0.442673    -0.206288      0.332598      1.499975
# AC004556.3      -1.752703     0.527289      0.723792      0.263258
# AC007325.4       1.630015    -0.908774     -0.034181      0.030627
# AC007325.2      -0.495318    -0.590937     -0.255759     -0.433426
#
#             DS_DSP.EN_1  CON_DS2U.RG  CON_H9.RG  CON_IMR.RG  DS_2DS3.RG  \
# Unnamed: 0
# ...

# %%
sns.heatmap(heatMapPlot, annot=False)
# Out:
# <AxesSubplot: ylabel='Unnamed: 0'>
